# %%
#!/usr/bin/env python

from decimal import Decimal

import mysql.connector
import os
import csv
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.keys import Keys
from datetime import datetime, timedelta
import selenium.webdriver.common.keys
import pandas as pd
from bs4 import BeautifulSoup
import csv
from datetime import datetime
import time
import sys


def main():
    import csv

    def get_unverified_rows(filename):
        unverified_rows = []
        try:
           with open(filename, 'r') as file:
             csv_reader = csv.reader(file)
             #next(csv_reader)  # Skip the header if present
             print("here is csv reader")

             for row in csv_reader:
                #print(f"Here is total row:{len(row)}")
                date, value, status, verification = row
                if verification.lower() == 'unverified':
                    unverified_rows.append(row)
        except Exception as e:
         print(f"The error is:{e}")
        print(f"this is unverified length -----{len(unverified_rows)}")
        

        return unverified_rows

    def update_row(filename, condition_row, new_status):
      with open(filename, 'r') as file:
        rows = list(csv.reader(file))
    
      with open(filename, 'w', newline='') as file:
        csv_writer = csv.writer(file)
        
        for row in rows:
            if row == condition_row:
                # Update the verification status
                row[3] = new_status
            csv_writer.writerow(row)  

    # Install the ChromeDriver executable and start a Chrome browser using Selenium
    driver = webdriver.Chrome()

    # Navigate to the webpage
    driver.get('https://merolagani.com/Floorsheet.aspx')
    filename = 'progress.csv'
    unverified_rows = get_unverified_rows(filename)
    print("Unverified row",unverified_rows)
    for row in unverified_rows:
        # Find the input element by its ID
        input_element = WebDriverWait(driver, 10).until(
            EC.element_to_be_clickable((By.ID, 'ctl00_ContentPlaceHolder1_txtFloorsheetDateFilter')))
        input_element.clear()
        input_element.send_keys(row[0])

        input_element.send_keys(Keys.ENTER)

        search_button = WebDriverWait(driver, 15).until(
            EC.element_to_be_clickable((By.ID, 'ctl00_ContentPlaceHolder1_lbtnSearchFloorsheet')))
        search_button.click()
        span_element = WebDriverWait(driver, 10).until(
            EC.presence_of_element_located((By.ID, 'ctl00_ContentPlaceHolder1_PagerControl1_litRecords'))
        )

        # Extract the total pages value from the content
        total_pages_text = span_element.text
        start_index = total_pages_text.find("[Total pages:") + len("[Total pages:")
        end_index = total_pages_text.find("]", start_index)

        total_pages_value = total_pages_text[start_index:end_index]
        num_pages_to_scrape = int(total_pages_value)
        print(f"Total pages: {num_pages_to_scrape} Check This!!")

        # Extract the text content of the span
        records_text = span_element.text

        # Extract the value of records using string manipulation
        start_index = records_text.find("of ") + len("of ")
        end_index = records_text.find(" records", start_index)

        records_value = records_text[start_index:end_index]
        print(f"Total Records: {records_value} Check This!!!")
        if int(records_value) - int(row[1]) > 480:
            update_row(filename, row, "failed")
            break

        else:
            update_row(filename, row, "passed")



    driver.quit()


if __name__ == "__main__":
    while True:
        try:
            main()
        except Exception as e:
            # Optionally, you can log the error to a file or another service
            time.sleep(5)  # Add a delay before restarting
            print(f"Restarting the program... {e}")
            continue
        except KeyboardInterrupt:
            print("Program terminated by user.")
            sys.exit()

# done
# Out:
# here is csv reader
# this is unverified length -----50
# Unverified row [['02/09/2023', '3538', 'completed', 'unverified'], ['02/12/2023', '51176', 'completed', 'unverified'], ['02/14/2023', '36837', 'completed', 'unverified'], ['02/15/2023', '33425', 'completed', 'unverified'], ['02/16/2023', '34997', 'completed', 'unverified'], ['02/20/2023', '38348', 'completed', 'unverified'], ['02/22/2023', '39908', 'completed', 'unverified'], ['02/23/2023', '47966', 'complet
/2023', '26814', 'completed', 'unverified'], ['03/14/2023', '26415', 'completed', 'unverified'], ['03/15/2023', '25456', 'completed', 'unverified'], ['03/16/2023', '26333', 'completed', 'unverified'], ['03/19/2023', '30728', 'completed', 'unverified'], ['03/20/2023', '29237', 'completed', 'unverified'], ['03/22/2023', '30441', 'completed', 'unverified'], ['03/23/2023', '2963', 'completed', 'unverified'], ['03/26/2023', '32134', 'completed', 'unverified'], ['03/27/2023', '36918', 'completed', 'unverified'], ['03/28/2023', '35877', 'completed', 'unverified'], ['03/29/2023', '25385', 'completed', 'unverified'], ['03/30/2023', '26397', 'completed', 'unverified'], ['04/02/2023', '32342', 'completed', 'unverified'], ['04/03/2023', '27415', 'completed', 'unverified'], ['04/04/2023', '23142', 'completed', 'unverified'], ['04/05/2023', '21456', 'completed', 'unverified'], ['04/06/2023', '23343', 'completed', 'unverified'], ['04/10/2023', '35502', 'completed', 'unverified'], ['04/11/2023', '35168', 'completed', 'unverified'], ['04/12/2023', '47207', 'completed', 'unverified'], ['04/13/2023', '44653', 'completed', 'unverified'], ['04/16/2023', '33097', 'completed', 'unverified'], ['04/09/2023', '29188', 'completed', 'unverified'], ['04/17/2023', '27388', 'completed', 'unverified'], ['04/18/2023', '24389', 'completed', 'unverified'], ['04/19/2023', '23472', 'completed', 'unverified'], ['04/20/2023', '23233', 'completed', 'unverified'], ['04/23/2023', '31370', 'completed', 'unverified'], ['04/24/2023', '33175', 'completed', 'unverified'], ['04/25/2023', '27722', 'completed', 'unverified'], ['04/26/2023', '23407', 'completed', 'unverified'], ['04/27/2023', '2182', 'completed', 'unverified']]
# Total pages: 103 Check This!!
# Total Records: 51226 Check This!!!
# Total pages: 74 Check This!!
# Total Records: 36880 Check This!!!
# Total pages: 67 Check This!!
# Total Records: 33483 Check This!!!
# Total pages: 71 Check This!!
# Total Records: 35079 Check This!!!
# Total pages: 77 Check This!!
# Total Records: 38415 Check This!!!
# Total pages: 80 Check This!!
# Total Records: 39996 Check This!!!
# Total pages: 97 Check This!!
# Total Records: 48105 Check This!!!
# Total pages: 102 Check This!!
# Total Records: 50532 Check This!!!
# Total pages: 75 Check This!!
# Total Records: 37338 Check This!!!
# Total pages: 58 Check This!!
# Total Records: 28684 Check This!!!
# Total pages: 53 Check This!!
# Total Records: 26454 Check This!!!
# Restarting the program... Message: no such execution context
#   (Session info: chrome=121.0.6167.85)
# Stacktrace:
# 0   chromedriver                        0x00000001032867dc chromedriver + 4040668
# 1   chromedriver                        0x000000010327e9e0 chromedriver + 4008416
# 2   chromedriver                        0x0000000102ef16a8 chromedriver + 284328
# 3   chromedriver                        0x0000000102edb1e8 chromedriver + 193000
# 4   chromedriver                        0x0000000102ed9144 chromedriver + 184644
# 5   chromedriver                        0x0000000102ed9c60 chromedriver + 187488
# 6   chromedriver                        0x0000000102ee8c00 chromedriver + 248832
# 7   chromedriver                        0x0000000102efc1a4 chromedriver + 328100
# 8   chromedriver                        0x0000000102eda220 chromedriver + 188960
# Stacktrace:
# 0   chromedriver                        0x00000001049f27dc chromedriver + 4040668
# 1   chromedriver                        0x00000001049ea9e0 chromedriver + 4008416
# 2   chromedriver                        0x000000010465d6a8 chromedriver + 284328
# 3   chromedriver                        0x00000001046471e8 chromedriver + 193000
# 4   chromedriver                        0x0000000104645144 chromedriver + 184644
# 5   chromedriver                        0x0000000104645c60 chromedriver + 187488
# 6   chromedriver                        0x0000000104654c00 chromedriver + 248832
# 7   chromedriver                        0x00000001046681a4 chromedriver + 328100
# 8   chromedriver                        0x0000000104646220 chromedriver + 188960
# 9   chromedriver                        0x0000000104667e00 chromedriver + 327168
# 10  chromedriver                        0x00000001046db220 chromedriver + 799264
# 11  chromedriver                        0x000000010469574c chromedriver + 513868
# 12  chromedriver                        0x0000000104696044 chromedriver + 516164
# 13  chromedriver                        0x00000001049b7a04 chromedriver + 3799556
# 14  chromedriver                        0x00000001049bbee4 chromedriver + 3817188
# 15  chromedriver                        0x00000001049a0260 chromedriver + 3703392
# 16  chromedriver                        0x00000001049bca2c chromedriver + 3820076
# 17  chromedriver                        0x000000010499301c chromedriver + 3649564
# 18  chromedriver                        0x00000001049d9e3c chromedriver + 3939900
# 19  chromedriver                        0x00000001049d9fb4 chromedriver + 3940276
# 20  chromedriver                        0x00000001049ea660 chromedriver + 4007520
# 21  libsystem_pthread.dylib             0x0000000187136034 _pthread_start + 136
# 22  libsystem_pthread.dylib             0x0000000187130e3c thread_start + 8
#
# here is csv reader
# this is unverified length -----36
# Unverified row [['03/07/2023', '24319', 'completed', 'unverified'], ['03/09/2023', '38059', 'completed', 'unverified'], ['03/12/2023', '36218', 'completed', 'unverified'], ['03/13/2023', '26814', 'completed', 'unverified'], ['03/14/2023', '26415', 'completed', 'unverified'], ['03/15/2023', '25456', 'completed', 'unverified'], ['03/16/2023', '26333', 'completed', 'unverified'], ['03/19/2023', '30728', 'completed', 'unverified'], ['03/20/2023', '29237', 'completed', 'unverified'], ['03/22/2023', '30441', 'completed', 'unverified'], ['03/23/2023', '2963', 'completed', 'unverified'], ['03/26/2023', '32134', 'completed', 'unverified'], ['03/27/2023', '36918', 'completed', 'unverified'], ['03/28/2023', '35877', 'completed', 'unverified'], ['03/29/2023', '25385', 'completed', 'unverified'], ['03/30/2023', '26397', 'completed', 'unverified'], ['04/02/2023', '32342', 'completed', 'unverified'], ['04/03/2023', '27415', 'completed', 'unverified'], ['04/04/2023', '23142', 'completed', 'unverified'], ['04/05/2023', '21456', 'completed', 'unverified'], ['04/06/2023', '23343', 'completed', 'unverified'], ['04/10/2023', '35502', 'completed', 'unverified'], ['04/11/2023', '35168', 'completed', 'unverified'], ['04/12/2023', '47207', 'completed', 'unverified'], ['04/13/2023', '44653', 'completed', 'unverified'], ['04/16/2023', '33097', 'completed', 'unverified'], ['04/09/2023', '29188', 'completed', 'unverified'], ['04/17/2023', '27388', 'completed', 'unverified'], ['04/18/2023', '24389', 'completed', 'unverified'], ['04/19/2023', '23472', 'completed', 'unverified'], ['04/20/2023', '23233', 'completed', 'unverified'], ['04/23/2023', '31370', 'completed', 'unverified'], ['04/24/2023', '33175', 'completed', 'unverified'], ['04/25/2023', '27722', 'completed', 'unverified'], ['04/26/2023', '23407', 'completed', 'unverified'], ['04/27/2023', '2182', 'completed', 'unverified']]
# Total pages: 49 Check This!!
# Total Records: 24373 Check This!!!
# Total pages: 77 Check This!!
# Total Records: 38131 Check This!!!
# Total pages: 73 Check This!!
# Total Records: 36280 Check This!!!
# Total pages: 54 Check This!!
# Total Records: 26850 Check This!!!
# Restarting the program... Message: no such execution context
#   (Session info: chrome=121.0.6167.85)
# Stacktrace:
# 0   chromedriver                        0x0000000104fba7dc chromedriver + 4040668
# 1   chromedriver                        0x0000000104fb29e0 chromedriver + 4008416
# 2   chromedriver                        0x0000000104c256a8 chromedriver + 284328
# 3   chromedriver                        0x0000000104c0f1e8 chromedriver + 193000
# 4   chromedriver                        0x0000000104c0d144 chromedriver + 184644
# 5   chromedriver                        0x0000000104c0dc60 chromedriver + 187488
# 6   chromedriver                        0x0000000104c1cc00 chromedriver + 248832
# 7   chromedriver                        0x0000000104c301a4 chromedriver + 328100
# 8   chromedriver                        0x0000000104c0e220 chromedriver + 188960
# 9   chromedriver                        0x0000000104c2fe00 chromedriver + 327168
# 10  chromedriver                        0x0000000104ca3220 chromedriver + 799264
# 11  chromedriver                        0x0000000104c5d74c chromedriver + 513868
# 12  chromedriver                        0x0000000104c5e044 chromedriver + 516164
# 13  chromedriver                        0x0000000104f7fa04 chromedriver + 3799556
# 14  chromedriver                        0x0000000104f83ee4 chromedriver + 3817188
# 15  chromedriver                        0x0000000104f68260 chromedriver + 3703392
# 16  chromedriver                        0x0000000104f84a2c chromedriver + 3820076
# 17  chromedriver                        0x0000000104f5b01c chromedriver + 3649564
# 18  chromedriver                        0x0000000104fa1e3c chromedriver + 3939900
# 19  chromedriver                        0x0000000104fa1fb4 chromedriver + 3940276
# 20  chromedriver                        0x0000000104fb2660 chromedriver + 4007520
# 21  libsystem_pthread.dylib             0x0000000187136034 _pthread_start + 136
# 22  libsystem_pthread.dylib             0x0000000187130e3c thread_start + 8
#
# here is csv reader
# this is unverified length -----32
# Unverified row [['03/14/2023', '26415', 'completed', 'unverified'], ['03/15/2023', '25456', 'completed', 'unverified'], ['03/16/2023', '26333', 'completed', 'unverified'], ['03/19/2023', '30728', 'completed', 'unverified'], ['03/20/2023', '29237', 'completed', 'unverified'], ['03/22/2023', '30441', 'completed', 'unverified'], ['03/23/2023', '2963', 'completed', 'unverified'], ['03/26/2023', '32134', 'completed', 'unverified'], ['03/27/2023', '36918', 'completed', 'unverified'], ['03/28/2023', '35877', 'completed', 'unverified'], ['03/29/2023', '25385', 'completed', 'unverified'], ['03/30/2023', '26397', 'completed', 'unverified'], ['04/02/2023', '32342', 'completed', 'unverified'], ['04/03/2023', '27415', 'completed', 'unverified'], ['04/04/2023', '23142', 'completed', 'unverified'], ['04/05/2023', '21456', 'completed', 'unverified'], ['04/06/2023', '23343', 'completed', 'unverified'], ['04/10/2023', '35502', 'completed', 'unverified'], ['04/11/2023', '35168', 'completed', 'unverified'], ['04/12/2023', '47207', 'completed', 'unverified'], ['04/13/2023', '44653', 'completed', 'unverified'], ['04/16/2023', '33097', 'completed', 'unverified'], ['04/09/2023', '29188', 'completed', 'unverified'], ['04/17/2023', '27388', 'completed', 'unverified'], ['04/18/2023', '24389', 'completed', 'unverified'], ['04/19/2023', '23472', 'completed', 'unverified'], ['04/20/2023', '23233', 'completed', 'unverified'], ['04/23/2023', '31370', 'completed', 'unverified'], ['04/24/2023', '33175', 'completed', 'unverified'], ['04/25/2023', '27722', 'completed', 'unverified'], ['04/26/2023', '23407', 'completed', 'unverified'], ['04/27/2023', '2182', 'completed', 'unverified']]
# Total pages: 53 Check This!!
# Total Records: 26473 Check This!!!
# Total pages: 51 Check This!!
# Total Records: 25491 Check This!!!
# Total pages: 53 Check This!!
# Total Records: 26375 Check This!!!
# Total pages: 62 Check This!!
# Total Records: 30775 Check This!!!
# Total pages: 59 Check This!!
# Total Records: 29282 Check This!!!
# Total pages: 61 Check This!!
# Total Records: 30485 Check This!!!
# Total pages: 60 Check This!!
# Total Records: 29685 Check This!!!
# here is csv reader
# this is unverified length -----25
# Unverified row [['03/26/2023', '32134', 'completed', 'unverified'], ['03/27/2023', '36918', 'completed', 'unverified'], ['03/28/2023', '35877', 'completed', 'unverified'], ['03/29/2023', '25385', 'completed', 'unverified'], ['03/30/2023', '26397', 'completed', 'unverified'], ['04/02/2023', '32342', 'completed', 'unverified'], ['04/03/2023', '27415', 'completed', 'unverified'], ['04/04/2023', '23142', 'completed', 'unverified'], ['04/05/2023', '21456', 'completed', 'unverified'], ['04/06/2023', '23343', 'completed', 'unverified'], ['04/10/2023', '35502', 'completed', 'unverified'], ['04/11/2023', '35168', 'completed', 'unverified'], ['04/12/2023', '47207', 'completed', 'unverified'], ['04/13/2023', '44653', 'completed', 'unverified'], ['04/16/2023', '33097', 'completed', 'unverified'], ['04/09/2023', '29188', 'completed', 'unverified'], ['04/17/2023', '27388', 'completed', 'unverified'], ['04/18/2023', '24389', 'completed', 'unverified'], ['04/19/2023', '23472', 'completed', 'unverified'], ['04/20/2023', '23233', 'completed', 'unverified'], ['04/23/2023', '31370', 'completed', 'unverified'], ['04/24/2023', '33175', 'completed', 'unverified'], ['04/25/2023', '27722', 'completed', 'unverified'], ['04/26/2023', '23407', 'completed', 'unverified'], ['04/27/2023', '2182', 'completed', 'unverified']]
# Total pages: 65 Check This!!
# Total Records: 32168 Check This!!!
# Total pages: 74 Check This!!
# Total Records: 36980 Check This!!!
# Total pages: 72 Check This!!
# Total Records: 35926 Check This!!!
# Total pages: 51 Check This!!
# Total Records: 25413 Check This!!!
# Total pages: 53 Check This!!
# Total Records: 26434 Check This!!!
# Total pages: 65 Check This!!
# Total Records: 32414 Check This!!!
# Total pages: 55 Check This!!
# Total Records: 27454 Check This!!!
# Total pages: 47 Check This!!
# Total Records: 23170 Check This!!!
# Total pages: 44 Check This!!
# Total Records: 21504 Check This!!!
# Total pages: 47 Check This!!
# Total Records: 23388 Check This!!!
# Total pages: 72 Check This!!
# Total Records: 35549 Check This!!!
# Total pages: 71 Check This!!
# Total Records: 35237 Check This!!!
# Total pages: 95 Check This!!
# Total Records: 47285 Check This!!!
# Total pages: 90 Check This!!
# Total Records: 44708 Check This!!!
# Total pages: 67 Check This!!
# Total Records: 33149 Check This!!!
# Total pages: 59 Check This!!
# Total Records: 29239 Check This!!!
# Total pages: 55 Check This!!
# Total Records: 27437 Check This!!!
# Total pages: 49 Check This!!
# Total Records: 24429 Check This!!!
# Total pages: 48 Check This!!
# Total Records: 23503 Check This!!!
# Total pages: 47 Check This!!
# Total Records: 23265 Check This!!!
# Total pages: 63 Check This!!
# Total Records: 31415 Check This!!!
# Total pages: 67 Check This!!
# Total Records: 33213 Check This!!!
# Total pages: 56 Check This!!
# Total Records: 27766 Check This!!!
# Restarting the program... Message: no such execution context
#   (Session info: chrome=121.0.6167.85)
# Stacktrace:
# 0   chromedriver                        0x00000001043de7dc chromedriver + 4040668
# 1   chromedriver                        0x00000001043d69e0 chromedriver + 4008416
# 2   chromedriver                        0x00000001040496a8 chromedriver + 284328
# 3   chromedriver                        0x00000001040331e8 chromedriver + 193000
# 4   chromedriver                        0x0000000104031144 chromedriver + 184644
# 5   chromedriver                        0x0000000104031c60 chromedriver + 187488
# 6   chromedriver                        0x0000000104040c00 chromedriver + 248832
# 7   chromedriver                        0x00000001040541a4 chromedriver + 328100
# 8   chromedriver                        0x0000000104032220 chromedriver + 188960
# 9   chromedriver                        0x0000000104053e00 chromedriver + 327168
# 10  chromedriver                        0x00000001040c7220 chromedriver + 799264
# 11  chromedriver                        0x000000010408174c chromedriver + 513868
# 12  chromedriver                        0x0000000104082044 chromedriver + 516164
# 13  chromedriver                        0x00000001043a3a04 chromedriver + 3799556
# 14  chromedriver                        0x00000001043a7ee4 chromedriver + 3817188
# 15  chromedriver                        0x000000010438c260 chromedriver + 3703392
# 16  chromedriver                        0x00000001043a8a2c chromedriver + 3820076
# 17  chromedriver                        0x000000010437f01c chromedriver + 3649564
# 18  chromedriver                        0x00000001043c5e3c chromedriver + 3939900
# 19  chromedriver                        0x00000001043c5fb4 chromedriver + 3940276
# 20  chromedriver                        0x00000001043d6660 chromedriver + 4007520
# 21  libsystem_pthread.dylib             0x0000000187136034 _pthread_start + 136
# 22  libsystem_pthread.dylib             0x0000000187130e3c thread_start + 8
#
# here is csv reader
# this is unverified length -----2
# Unverified row [['04/26/2023', '23407', 'completed', 'unverified'], ['04/27/2023', '2182', 'completed', 'unverified']]
# Total pages: 47 Check This!!
# Total Records: 23429 Check This!!!
# Total pages: 44 Check This!!
# Total Records: 21851 Check This!!!
# here is csv reader
# this is unverified length -----0
# Unverified row []
# here is csv reader
# this is unverified length -----0
# Unverified row []
# here is csv reader
# this is unverified length -----0
# Unverified row []
# here is csv reader
# this is unverified length -----0
# Unverified row []
# here is csv reader
# this is unverified length -----0
# Unverified row []
# here is csv reader
# this is unverified length -----0
# Unverified row []
# here is csv reader
# this is unverified length -----0
# Unverified row []
# here is csv reader
# this is unverified length -----0
# Unverified row []
# here is csv reader
# this is unverified length -----0
# Unverified row []
# here is csv reader
# this is unverified length -----0
# Unverified row []
# here is csv reader
# this is unverified length -----0
# Unverified row []
# here is csv reader
# this is unverified length -----0
# Unverified row []
# here is csv reader
# this is unverified length -----0
# Unverified row []
# here is csv reader
# this is unverified length -----0
# Unverified row []
# here is csv reader
# this is unverified length -----0
# Unverified row []
# here is csv reader
# this is unverified length -----0
# Unverified row []
# here is csv reader
# this is unverified length -----0
# Unverified row []
# here is csv reader
# this is unverified length -----0
# Unverified row []
# here is csv reader
# this is unverified length -----0
# Unverified row []
# here is csv reader
# this is unverified length -----0
# Unverified row []
# here is csv reader
# this is unverified length -----0
# Unverified row []
# here is csv reader
# this is unverified length -----0
# Unverified row []
# Program terminated by user.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 117
#     116 try:
# --> 117     main()
#     118 except Exception as e:
#     119     # Optionally, you can log the error to a file or another service
#
# Cell In[35], line 64, in main()
#      63 # Navigate to the webpage
# ---> 64 driver.get('https://merolagani.com/Floorsheet.aspx')
#      65 filename = 'progress.csv'
#
# File /Applications/Utilities/anaconda3/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py:357, in WebDriver.get(self, url)
#     356 """Loads a web page in the current browser session."""
# --> 357 self.execute(Command.GET, {"url": url})
#
# File /Applications/Utilities/anaconda3/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py:346, in WebDriver.execute(self, driver_command, params)
#     344         params["sessionId"] = self.session_id
# --> 346 response = self.command_executor.execute(driver_command, params)
#     347 if response:
#
# File /Applications/Utilities/anaconda3/lib/python3.11/site-packages/selenium/webdriver/remote/remote_connection.py:300, in RemoteConnection.execute(self, command, params)
#     299 url = f"{self._url}{path}"
# --> 300 return self._request(command_info[0], url, body=data)
#
# File /Applications/Utilities/anaconda3/lib/python3.11/site-packages/selenium/webdriver/remote/remote_connection.py:321, in RemoteConnection._request(self, method, url, body)
#     320 if self.keep_alive:
# --> 321     response = self._conn.request(method, url, body=body, headers=headers)
#     322     statuscode = response.status
#
# File /Applications/Utilities/anaconda3/lib/python3.11/site-packages/urllib3/request.py:81, in RequestMethods.request(self, method, url, fields, headers, **urlopen_kw)
#      80 else:
# ---> 81     return self.request_encode_body(
#      82         method, url, fields=fields, headers=headers, **urlopen_kw
#      83     )
#
# File /Applications/Utilities/anaconda3/lib/python3.11/site-packages/urllib3/request.py:173, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     171 extra_kw.update(urlopen_kw)
# --> 173 return self.urlopen(method, url, **extra_kw)
#
# File /Applications/Utilities/anaconda3/lib/python3.11/site-packages/urllib3/poolmanager.py:376, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     375 else:
# --> 376     response = conn.urlopen(method, u.request_uri, **kw)
#     378 redirect_location = redirect and response.get_redirect_location()
#
# File /Applications/Utilities/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:715, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     714 # Make the request on the httplib connection object.
# --> 715 httplib_response = self._make_request(
#     716     conn,
#     717     method,
#     718     url,
#     719     timeout=timeout_obj,
#     720     body=body,
#     721     headers=headers,
#     722     chunked=chunked,
#     723 )
#     725 # If we're going to release the connection in ``finally:``, then
#     726 # the response doesn't need to know about the connection. Otherwise
#     727 # it will also try to release it and we'll have a double-release
#     728 # mess.
#
# File /Applications/Utilities/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     463         except BaseException as e:
#     464             # Remove the TypeError from the exception chain in
#     465             # Python 3 (including for exceptions like SystemExit).
#     466             # Otherwise it looks like a bug in the code.
# --> 467             six.raise_from(e, None)
#     468 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File /Applications/Utilities/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:462, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     461 try:
# --> 462     httplib_response = conn.getresponse()
#     463 except BaseException as e:
#     464     # Remove the TypeError from the exception chain in
#     465     # Python 3 (including for exceptions like SystemExit).
#     466     # Otherwise it looks like a bug in the code.
#
# File /Applications/Utilities/anaconda3/lib/python3.11/http/client.py:1386, in HTTPConnection.getresponse(self)
#    1385 try:
# -> 1386     response.begin()
#    1387 except ConnectionError:
#
# File /Applications/Utilities/anaconda3/lib/python3.11/http/client.py:325, in HTTPResponse.begin(self)
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#
# File /Applications/Utilities/anaconda3/lib/python3.11/http/client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#
# File /Applications/Utilities/anaconda3/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     705 try:
# --> 706     return self._sock.recv_into(b)
#     707 except timeout:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[35], line 125
#     124 print("Program terminated by user.")
# --> 125 sys.exit()
#
# SystemExit:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File /Applications/Utilities/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2121, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2118 if exception_only:
#    2119     stb = ['An exception has occurred, use %tb to see '
#    2120            'the full traceback.\n']
# -> 2121     stb.extend(self.InteractiveTB.get_exception_only(etype,
#    2122                                                      value))
#    2123 else:
#    2125     def contains_exceptiongroup(val):
#
# File /Applications/Utilities/anaconda3/lib/python3.11/site-packages/IPython/core/ultratb.py:710, in ListTB.get_exception_only(self, etype, value)
#     702 def get_exception_only(self, etype, value):
#     703     """Only print the exception type and message, without a traceback.
#     704
#     705     Parameters
#    (...)
#     708     value : exception value
#     709     """
# --> 710     return ListTB.structured_traceback(self, etype, value)
#
# File /Applications/Utilities/anaconda3/lib/python3.11/site-packages/IPython/core/ultratb.py:568, in ListTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     565     chained_exc_ids.add(id(exception[1]))
#     566     chained_exceptions_tb_offset = 0
#     567     out_list = (
# --> 568         self.structured_traceback(
#     569             etype,
#     570             evalue,
#     571             (etb, chained_exc_ids),  # type: ignore
#     572             chained_exceptions_tb_offset,
#     573             context,
#     574         )
#     575         + chained_exception_message
#     576         + out_list)
#     578 return out_list
#
# File /Applications/Utilities/anaconda3/lib/python3.11/site-packages/IPython/core/ultratb.py:1435, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1433 else:
#    1434     self.tb = etb
# -> 1435 return FormattedTB.structured_traceback(
#    1436     self, etype, evalue, etb, tb_offset, number_of_lines_of_context
#    1437 )
#
# File /Applications/Utilities/anaconda3/lib/python3.11/site-packages/IPython/core/ultratb.py:1326, in FormattedTB.structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1323 mode = self.mode
#    1324 if mode in self.verbose_modes:
#    1325     # Verbose modes need a full traceback
# -> 1326     return VerboseTB.structured_traceback(
#    1327         self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1328     )
#    1329 elif mode == 'Minimal':
#    1330     return ListTB.get_exception_only(self, etype, value)
#
# File /Applications/Utilities/anaconda3/lib/python3.11/site-packages/IPython/core/ultratb.py:1173, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1164 def structured_traceback(
#    1165     self,
#    1166     etype: type,
#    (...)
#    1170     number_of_lines_of_context: int = 5,
#    1171 ):
#    1172     """Return a nice text document describing the traceback."""
# -> 1173     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1174                                                            tb_offset)
#    1176     colors = self.Colors  # just a shorthand + quicker name lookup
#    1177     colorsnormal = colors.Normal  # used a lot
#
# File /Applications/Utilities/anaconda3/lib/python3.11/site-packages/IPython/core/ultratb.py:1063, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1060 assert isinstance(tb_offset, int)
#    1061 head = self.prepare_header(str(etype), self.long_header)
#    1062 records = (
# -> 1063     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#    1064 )
#    1066 frames = []
#    1067 skipped = 0
#
# File /Applications/Utilities/anaconda3/lib/python3.11/site-packages/IPython/core/ultratb.py:1131, in VerboseTB.get_records(self, etb, number_of_lines_of_context, tb_offset)
#    1129 while cf is not None:
#    1130     try:
# -> 1131         mod = inspect.getmodule(cf.tb_frame)
#    1132         if mod is not None:
#    1133             mod_name = mod.__name__
#
# AttributeError: 'tuple' object has no attribute 'tb_frame'
