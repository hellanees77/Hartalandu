# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup

# %%
url = 'https://www.nepalstock.com.np/floor-sheet'

# %%
# Set up the browser options
chrome_options = Options()
#chrome_options.add_argument('--headless')  
# Run Chrome in headless mode (no GUI)

# %%
# Create a WebDriver instance
driver = webdriver.Chrome(options=chrome_options)

# %%
# Load the page
driver.get(url)

# %%
# Wait for a few seconds to allow dynamic content to load (you might need to adjust this)
driver.implicitly_wait(1000)

# %%
# Get the page source after JavaScript execution
page_source = driver.page_source

# %%
# Close the browser
driver.quit()

# %%
# Use BeautifulSoup to parse the page source
soup = BeautifulSoup(page_source, 'html.parser')

# %%
# Print all text content
print(soup)
# Out:
# <html lang="en"><head>
# <meta charset="utf-8"/>
# <title>Nepal Stock Exchange</title>
# <base href="/"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="assets/img/favicon.ico" rel="icon" type="image/x-icon"/>
# <link href="https://fonts.googleapis.com/css?family=Roboto" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/css?family=Noto+Sans:400,700&amp;display=swap" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Source+Sans+Pro:400,600,700" rel="stylesheet"/>
# <link href="https://use.fontawesome.com/releases/v5.8.1/css/all.css" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Roboto:300,400,500" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"/>
# <link href="styles.552ced02a43746331a6d.css" rel="stylesheet"/><style>.cursor[_ngcontent-xka-c0]{cursor:pointer}.main[_ngcontent-xka-c0]{max-width:100%;width:100%}</style><style>.external-link{color:#fff;cursor:pointer!important}.betaTag{position:relative}.betaTag::after{content:"BETA";position:absolute;font-size:13px;top:3px;right:-30px;color:#fff;background:#fe6767;padding:2px 4px;border-radius:10px;font-weight:100}.beta-msg{padding:.3rem;text-align:center;background:#fe6767;color:#fff;font-weight:700}.visit-nepal{display:inline;height:70px;width:105px!important;margin-top:-16px;margin-left:26px}.menu-container{padding:0 2rem;margin:0 auto;min-width:96%;display:flex;flex-wrap:wrap;flex-direction:row;justify-content:space-around}a.item{margin:0 .6rem;font-size:1.2rem}@media (max-width:1250px){a.item{margin:0 .3rem;font-size:1rem}}typeahead-container.dropdown.open.dropdown-menu .dropdown-item{border-bottom:1px solid #efefef;max-width:40em!important;white-space:pre-wrap!important;font-size:14px!important;padding:10px;min-width:21em!important}.dropdown.open.dropdown-menu{max-height:220px!important;min-height:1.5em!important}@media(min-width:390px) and (max-width:550px){typeahead-container.dropdown.open.dropdown-menu .dropdown-item{max-width:90vw!important}}@media(max-width:390px){typeahead-container.dropdown.open.dropdown-menu .dropdown-item{max-width:360px!important}.dropdown-menu{min-width:20rem!important}}</style><style>.ticker[_ngcontent-xka-c3]{background:#d3d3d3;padding:5px 20px;overflow:hidden}.ticker__date[_ngcontent-xka-c3]{float:left;font-size:12px;font-weight:400;padding-right:10px;border-right:1px solid #828282;color:#4f4f4f}.ticker__wrap[_ngcontent-xka-c3]{overflow:hidden}.ticker__wrap[_ngcontent-xka-c3]   li[_ngcontent-xka-c3]{float:left}.ticker__add[_ngcontent-xka-c3]{float:right;padding-left:20px}.ticker__add--btn[_ngcontent-xka-c3]{padding:5px;display:block;width:20px;height:20px;line-height:20px;text-align:center;background:#cfdbee;font-size:10px;color:#0078d7;cursor:pointer;border-radius:50%;transition:all .33s}.ticker__add--btn[_ngcontent-xka-c3]:hover{color:#828282;background:#dbdbdb}.ticker__add--btn[_ngcontent-xka-c3]   i[_ngcontent-xka-c3]{display:inline-block;vertical-align:middle;line-height:1}.ticker__container[_ngcontent-xka-c3]{position:relative;list-style-type:none;margin:0;padding:0;display:inline-block;font-family:Roboto,sans-serif!important;font-size:12px!important}.ticker__block[_ngcontent-xka-c3]{margin-left:20px;font-weight:600;transition:all .33s}.ticker__block[_ngcontent-xka-c3]:hover{color:#4f4f4f}.ticker__block--percentage[_ngcontent-xka-c3]   i[_ngcontent-xka-c3]{font-size:8px;display:inline-block;vertical-align:middle;line-height:1}.changenone[_ngcontent-xka-c3]{color:#0078d7}.changedown[_ngcontent-xka-c3]{color:#ed254e}.changeup[_ngcontent-xka-c3]{color:#1eb700}.arrow-size[_ngcontent-xka-c3]{font-size:15px}a[_ngcontent-xka-c3]{color:inherit;text-decoration:none}</style><style>.symbol-search{width:400px}@media (max-width:767px){.symbol-search{width:100%}}</style><style></style><style>
# .ngx-pagination {
#   margin-left: 0;
#   margin-bottom: 1rem; }
#   .ngx-pagination::before, .ngx-pagination::after {
#     content: ' ';
#     display: table; }
#   .ngx-pagination::after {
#     clear: both; }
#   .ngx-pagination li {
#     -moz-user-select: none;
#     -webkit-user-select: none;
#     -ms-user-select: none;
#     margin-right: 0.0625rem;
#     border-radius: 0; }
#   .ngx-pagination li {
#     display: inline-block; }
#   .ngx-pagination a,
#   .ngx-pagination button {
#     color: #0a0a0a;
#     display: block;
#     padding: 0.1875rem 0.625rem;
#     border-radius: 0; }
#     .ngx-pagination a:hover,
#     .ngx-pagination button:hover {
#       background: #e6e6e6; }
#   .ngx-pagination .current {
#     padding: 0.1875rem 0.625rem;
#     background: #2199e8;
#     color: #fefefe;
#     cursor: default; }
#   .ngx-pagination .disabled {
#     padding: 0.1875rem 0.625rem;
#     color: #cacaca;
#     cursor: default; }
#     .ngx-pagination .disabled:hover {
#       background: transparent; }
#   .ngx-pagination a, .ngx-pagination button {
#     cursor: pointer; }
#
# .ngx-pagination .pagination-previous a::before,
# .ngx-pagination .pagination-previous.disabled::before {
#   content: '«';
#   display: inline-block;
#   margin-right: 0.5rem; }
#
# .ngx-pagination .pagination-next a::after,
# .ngx-pagination .pagination-next.disabled::after {
#   content: '»';
#   display: inline-block;
#   margin-left: 0.5rem; }
#
# .ngx-pagination .show-for-sr {
#   position: absolute !important;
#   width: 1px;
#   height: 1px;
#   overflow: hidden;
#   clip: rect(0, 0, 0, 0); }
# .ngx-pagination .small-screen {
#   display: none; }
# @media screen and (max-width: 601px) {
#   .ngx-pagination.responsive .small-screen {
#     display: inline-block; }
#   .ngx-pagination.responsive li:not(.small-screen):not(.pagination-previous):not(.pagination-next) {
#     display: none; }
# }
#   </style></head>
# <body oncontextmenu="return false;">
# <div class="preloader">
# <div class="load hide">
# <div class="load__wrap">
# <div class="load__out">
# <div class="load__in">
# <span>NEPSE</span>
# </div>
# </div>
# <span class="load__text"> Loading... </span>
# </div>
# </div>
# </div>
# <app-root _nghost-xka-c0="" ng-version="7.2.16"><!-- --><div _ngcontent-xka-c0=""><!-- --><app-header _ngcontent-xka-c0=""><header class="header"><div class="header__main"><div class="container"><div class="header__top d-flex flex-column flex-lg-row justify-content-between"><div class="header__logo d-flex align-items-center"><a href="#"><img alt="Nepal Stock Exchange" src="assets/img/logo.png"/></a><button aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation" class="d-block d-lg-none header__responsivemenu navbar-toggler ml-auto" data-target="#topnavbar" data-toggle="collapse" type="button"><span class="fas fa-align-justify"></span></button></div><div class="header__search d-flex flex-column align-items-end"><div class="header__nav navbar navbar-expand-lg"><nav class="header__nav--wrap collapse navbar-collapse" id="topnavbar"><ul class="d-flex navbar-nav" data-target=".navbar-collapse.show" data-toggle="collapse"><li><a href="/holiday-listing" routerlink="/holiday-listing">Holiday's Listing</a></li><li><a href="/today-price" routerlink="/today-price">Today's Price</a></li><li><a href="/marketdepth" routerlink="/marketdepth">Market Depth</a></li><li><a href="/floor-sheet" routerlink="/floor-sheet">Floor Sheet</a></li><li><a href="/downloads" routerlink="/downloads">Downloads</a></li><li><a href="/about-us/contact-us" routerlink="/about-us/contact-us">Contact Us</a></li><li><a href="https://www.youtube.com/watch?v=Df06a7O7RuE&amp;lc=z22aijhamzy5vdd3oacdp432erg0i5bvw4eysaay1lpw03c010c" target="_blank">Video Tutorial</a></li><li><a href="http://old.nepalstock.com/" target="_blank">Old Website</a></li><li><a href="/faq" routerlink="/faq">FAQ</a></li></ul></nav></div><div class="header__search--box"><div class="header__search--wrap"><input class="ng-untouched ng-pristine ng-valid" placeholder="Search by Symbol or Company Name..." style="position: relative; left: -8px;" typeaheadoptionfield="name"/><button name="search" type="button"><i class="fas fa-search"></i></button></div></div></div></div><nav class="sitenav navbar navbar-expand-lg"><button aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation" class="sitenav__responsivemenu navbar-toggler ml-auto" data-target="#sitenavbar" data-toggle="collapse" type="button"><span class="fas fa-align-justify"></span></button><div class="collapse navbar-collapse" id="sitenavbar"><div class="m" enu-container=""><ul class="navbar-nav" data-target=".navbar-collapse.show" data-toggle="collapse"><li class="nav-item active"><a class="nav-link item" href="/" routerlink="/">Home</a></li><!-- --><li class="nav-item dropdown"><!-- --><!-- --><!-- --><a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle item" data-toggle="dropdown" href="#" id="navbarDropdown" role="button"> NEPSE Data </a><!-- --></li><li class="nav-item dropdown"><!-- --><!-- --><!-- --><a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle item" data-toggle="dropdown" href="#" id="navbarDropdown" role="button"> About Us </a><!-- --></li><li class="nav-item dropdown"><!-- --><!-- --><!-- --><a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle item" data-toggle="dropdown" href="#" id="navbarDropdown" role="button"> Media </a><!-- --></li><li class="nav-item active"><!-- --><a class="nav-link item" href="/events">Events</a><!-- --><!-- --><!-- --></li><li class="nav-item dropdown"><!-- --><!-- --><!-- --><a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle item" data-toggle="dropdown" href="#" id="navbarDropdown" role="button"> Member </a><!-- --></li><li class="nav-item dropdown"><!-- --><!-- --><!-- --><a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle item" data-toggle="dropdown" href="#" id="navbarDropdown" role="button"> Company </a><!-- --></li><li class="nav-item dropdown"><!-- --><!-- --><!-- --><a aria-expanded="false" aria-haspopup= ...
# <script src="runtime.c7c98e1287453fa31bed.js" type="text/javascript"></script><script nomodule="" src="es2015-polyfills.8db7493dfa2eeba86bd5.js" type="text/javascript"></script><script src="polyfills.d9c6f42c392d3399d7b1.js" type="text/javascript"></script><script src="scripts.78fbe7d668d564c4f55e.js" type="text/javascript"></script><script src="main.bbc3f6b0d197dc978a61.js" type="text/javascript"></script>
# <script>
#     // $(document).ready(function(){
#     //   $("#index__more").on('click', function(e){
#     //       e.preventDefault();
#     //       $('.index__chart').toggleClass('move');
#     //       $('.index__subindices').toggleClass('show');
#     //     });
#
#     //     $('.index__subindices--overlay').on('click', function(e){
#     //       $('.index__chart').removeClass('move');
#     //       $('.index__subindices').removeClass('show');
#     //     });
#
#     $("#disclaim").on("click", function (e) {
#       $(".beta").toggleClass("show");
#     });
#     // });
#
#     (function () {
#       let loader = document.querySelector(".load");
#       loader.classList.add("hide");
#     })();
#
#     //   $(function () {
#     //       $('[data-toggle="tooltip"]').tooltip()
#     //     });
#     var Module = {
#       locateFile: function (s) {
#         return "html" + s;
#       },
#     };
#   </script>
# </body></html>
